# %% [markdown]
# Connected to rl_thesis (Python 3.14.6)

# %%
from .env_parallel import FreeAgencyEnv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 #%%
# ----> 2 from .env_parallel import FreeAgencyEnv
#
# ImportError: attempted relative import with no known parent package

# %%
from env_parallel import FreeAgencyEnv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 #%%
# ----> 2 from env_parallel import FreeAgencyEnv
#
# File ~/nba_thesis/free_agency_refactor/free_agency/env_parallel.py:17
#      14 from pettingzoo.utils import AgentSelector
#      15 from gymnasium.utils import seeding
# ---> 17 from .constants import LeagueConfig, N_PLAYER_COLS, HISTORY_WINDOW, CAP_HORIZON
#      18 from .state import LeagueState, new_league_state, record_season_history, agent_to_team_id
#      19 # from .contracts import handle_signing, contract_update, make_action_mask
#
# ImportError: attempted relative import with no known parent package

# %%
from free_agency.env_parallel import FreeAgencyEnv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #%%
# ----> 2 from free_agency.env_parallel import FreeAgencyEnv
#
# ModuleNotFoundError: No module named 'free_agency'

# %%
from pathlib import Path
import sys

project_root = Path(__file__).resolve().parent.parent
sys.path.insert(0, str(project_root))
from free_agency.env_parallel import FreeAgencyEnv

# %%
env = FreeAgencyEnv(render_mode="human")
observations, infos = env.reset()

print(observations)
print(infos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #%%
# ----> 2 env = FreeAgencyEnv(render_mode="human")
#       3 observations, infos = env.reset()
#       5 print(observations)
#
# File ~/nba_thesis/free_agency_refactor/free_agency/env_parallel.py:38, in FreeAgencyEnv.__init__(self, render_mode, config)
#      35 self.agent_name_mapping = dict(zip(self.possible_agents, nba_teams))
#      36 self.render_mode = render_mode
# ---> 38 self.league = new_league_state(self.config, self.possible_agents)
#      39 self.g_list = generate_exact_nba_schedule(self.config.n_teams)
#      40 self.season = 0
#
# File ~/nba_thesis/free_agency_refactor/free_agency/state.py:33, in new_league_state(config, possible_agents)
#      32 def new_league_state(config: LeagueConfig, possible_agents: list[str]) -> LeagueState:
# ---> 33     players = _generate_players(config.n_players)
#      34     teams = {agent: np.zeros(config.players_per_team) for agent in possible_agents}
#      35     team_salaries = {agent: 0.0 for agent in possible_agents}
#
# File ~/nba_thesis/free_agency_refactor/free_agency/state.py:65, in _generate_players(n_players, age_mean, age_std, rating_shape)
#      63 def _generate_players(n_players: int, age_mean: float = 27, age_std: float = 4,
#      64                        rating_shape: float = 1.0) -> np.ndarray:
# ---> 65     ratings = sorted(stats.lognorm.rvs(loc=0, s=rating_shape, size=n_players), reverse=True)
#      66     zero_array = np.zeros(n_players) # Used for teams, contract_lens, salaries, and offers
#      67     # teams = np.zeros(n_players)
#
# File ~/.conda/envs/rl_thesis/lib/python3.14/site-packages/scipy/stats/_distn_infrastructure.py:1132, in rv_generic.rvs(self, *args, **kwds)
#    1129 else:
#    1130     random_state = self._random_state
# -> 1132 vals = self._rvs(*args, size=size, random_state=random_state)
#    1134 vals = vals * scale + loc
#    1136 # do not forget to restore the _random_state
#
# File ~/.conda/envs/rl_thesis/lib/python3.14/site-packages/scipy/stats/_continuous_distns.py:6910, in lognorm_gen._rvs(self, s, size, random_state)
#    6909     def _rvs(self, s, size=None, random_state=None):
# -> 6910         return np.exp(s * random_state.standard_normal(size))
#
# File numpy/random/mtrand.pyx:1470, in numpy.random.mtrand.RandomState.standard_normal()
# -> 1470 'Could not get source, probably due dynamically evaluated source code.'
#
# File numpy/random/_common.pyx:654, in numpy.random._common.cont()
# --> 654 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
from pathlib import Path
import sys

project_root = Path(__file__).resolve().parent.parent
sys.path.insert(0, str(project_root))
from free_agency.env_parallel import FreeAgencyEnv

# %%
env = FreeAgencyEnv(render_mode="human")
observations, infos = env.reset()

print(observations)
print(infos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #%%
# ----> 2 env = FreeAgencyEnv(render_mode="human")
#       3 observations, infos = env.reset()
#       5 print(observations)
#
# File ~/nba_thesis/free_agency_refactor/free_agency/env_parallel.py:38, in FreeAgencyEnv.__init__(self, render_mode, config)
#      35 self.agent_name_mapping = dict(zip(self.possible_agents, nba_teams))
#      36 self.render_mode = render_mode
# ---> 38 self.league = new_league_state(self.config, self.possible_agents)
#      39 self.g_list = generate_exact_nba_schedule(self.config.n_teams)
#      40 self.season = 0
#
# File ~/nba_thesis/free_agency_refactor/free_agency/state.py:33, in new_league_state(config, possible_agents)
#      32 def new_league_state(config: LeagueConfig, possible_agents: list[str]) -> LeagueState:
# ---> 33     players = _generate_players(config.n_players)
#      34     teams = {agent: np.zeros(config.players_per_team) for agent in possible_agents}
#      35     team_salaries = {agent: 0.0 for agent in possible_agents}
#
# File ~/nba_thesis/free_agency_refactor/free_agency/state.py:65, in _generate_players(n_players, age_mean, age_std, rating_shape)
#      63 def _generate_players(n_players: int, age_mean: float = 27, age_std: float = 4,
#      64                        rating_shape: float = 1.0) -> np.ndarray:
# ---> 65     ratings = sorted(stats.lognorm.rvs(loc=0, s=rating_shape, size=n_players), reverse=True)
#      66     zero_array = np.zeros(n_players) # Used for teams, contract_lens, salaries, and offers
#      67     # teams = np.zeros(n_players)
#
# File ~/.conda/envs/rl_thesis/lib/python3.14/site-packages/scipy/stats/_distn_infrastructure.py:1132, in rv_generic.rvs(self, *args, **kwds)
#    1129 else:
#    1130     random_state = self._random_state
# -> 1132 vals = self._rvs(*args, size=size, random_state=random_state)
#    1134 vals = vals * scale + loc
#    1136 # do not forget to restore the _random_state
#
# File ~/.conda/envs/rl_thesis/lib/python3.14/site-packages/scipy/stats/_continuous_distns.py:6910, in lognorm_gen._rvs(self, s, size, random_state)
#    6909     def _rvs(self, s, size=None, random_state=None):
# -> 6910         return np.exp(s * random_state.standard_normal(size))
#
# File numpy/random/mtrand.pyx:1470, in numpy.random.mtrand.RandomState.standard_normal()
# -> 1470 'Could not get source, probably due dynamically evaluated source code.'
#
# File numpy/random/_common.pyx:654, in numpy.random._common.cont()
# --> 654 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer
